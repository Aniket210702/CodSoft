# %% [markdown]
# #Name: Aniket Chattopadhyay
# #Batch: NOV BATCH A14
# #Field: DATA SCIENCE

# %% [markdown]
# ##Task : Credit Card Fraud Detection (Task 5)

# %% [markdown]
# Here we build a machine learning model to identify fraudulent credit card
# transactions.
#
# > First we preprocess and normalize the transaction data, handle class
# imbalance issues, and split the dataset into training and testing sets and train a classification algorithm, such as logistic regression or random
# forests, to classify transactions as fraudulent or genuine.
#
# > Up next we evaluate the model's performance using metrics like precision, recall, and F1-score, and consider techniques like oversampling or
# undersampling for improving results.

# %% [markdown]
# # Data preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("creditcard.csv")
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.countplot(x='Class', data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
df['Amount'] = StandardScaler().fit_transform(df['Amount'].values.reshape(-1, 1))
df['Time'] = StandardScaler().fit_transform(df['Time'].values.reshape(-1, 1))
df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
from sklearn.svm import OneClassSVM

# %%
clf = OneClassSVM(kernel='rbf', gamma=0.001, nu=0.01)
clf.fit(df)
# Out:
# OneClassSVM(gamma=0.001, nu=0.01)

# %%
y_pred = clf.predict(df)
y_pred = y_pred.reshape(-1,1)

# %%
print("Number of outliers:", len(df[y_pred == -1]))
# Out:
# Number of outliers: 2847

# %% [markdown]
# # Splitting of data into training and testing data

# %%
x = df.drop('Class', axis=1)
x.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0  0.239599  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474
# 1 -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.791461  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.237609  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321
# 4  0.592941 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28    Amount
# ...

# %%
y = df['Class']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((227845, 30), (56962, 30), (227845,), (56962,))

# %%
x_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223361  1.022112  1.955041 -0.380783 -0.315013  0.330155 -0.509374 -0.086197
# 165061  0.470837 -0.400975 -0.626943  1.555339 -2.017772 -0.107769  0.168310
# 238186  1.152945  0.072509  0.820566 -0.561351 -0.709897  1.080399 -0.359429
# 150562 -0.024087 -0.535045  1.014587  1.750679  2.769390  0.500089  1.002270
# 138452 -0.256040 -4.026938  1.897371 -0.429786 -0.029571 -0.855751 -0.480406
# ...          ...       ...       ...       ...       ...       ...       ...
# 119879 -0.404225  1.173488  0.100792  0.490512  0.461596 -0.296377 -0.213165
# 259178  1.351627 -0.775981  0.144023 -1.142399 -1.241113  1.940358  3.912076
# 131932 -0.316266 -0.146609  0.992946  1.524591  0.485774  0.349308 -0.815198
# 146867 -0.144939 -2.948638  2.354849 -2.521201 -3.798905  1.866302  2.727695
# 121958 -0.388158  1.233174 -0.784851  0.386784 -0.698559 -1.034018 -0.637028
#
# ...

# %%
x_test
# Out:
#             Time         V1        V2         V3        V4         V5  \
# 43428  -1.122574 -16.526507  8.584972 -18.649853  9.505594 -13.793819
# 49906  -1.064538   0.339812 -2.743745  -0.134070 -1.385729  -1.451413
# 29474  -1.249364   1.399590 -0.590701   0.168619 -1.029950  -0.539806
# 276481  1.522680  -0.432071  1.647895  -1.669361 -0.349504   0.785785
# 278846  1.551109   2.014160 -0.137394  -1.015839  0.327269  -0.182179
# ...          ...        ...       ...        ...       ...        ...
# 75723  -0.812643  -1.994348  1.503076  -0.365560  0.780223  -0.957956
# 252263  1.282683  -0.234567  0.733694   0.486250 -0.718186   0.782227
# 221246  1.003982   0.040441 -0.109737  -1.266430  1.004783   2.223390
# 81910  -0.750859  -0.495048  0.991481   1.671584 -0.342474   0.470012
# 59490  -0.967609  -1.590486  0.992415  -0.512841  1.120752  -1.916756
#
#               V6         V7        V8        V9  ...       V20       V21  \
# ...

# %% [markdown]
# #Creating model

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# 43428     1
# 49906     0
# 29474     0
# 276481    0
# 278846    0
#          ..
# 75723     0
# 252263    0
# 221246    0
# 81910     0
# 59490     0
# Name: Class, Length: 56962, dtype: int64

# %%
df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  1.641931 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  1.641952  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  1.641974   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  1.641974  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  1.642058  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# ...

# %% [markdown]
# #Model conclusions

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9991222218320986

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.86      0.58      0.70        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.79      0.85     56962
# weighted avg       1.00      1.00      1.00     56962
